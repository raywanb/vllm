# %%
from huggingface_hub import snapshot_download

sql_lora_path = snapshot_download(repo_id="yard1/llama-2-7b-sql-lora-test")

# %%
from vllm import LLM, SamplingParams
from vllm.lora.request import LoRARequest

llm = LLM(model="meta-llama/Llama-2-7b-hf", enable_lora=True)
# Out:
# INFO 04-28 21:40:17 llm_engine.py:98] Initializing an LLM engine (v0.4.1) with config: model='meta-llama/Llama-2-7b-hf', speculative_config=None, tokenizer='meta-llama/Llama-2-7b-hf', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, disable_custom_all_reduce=Falsequantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), seed=0)
# INFO 04-28 21:40:17 utils.py:620] Found nccl from library /root/.config/vllm/nccl/cu12/libnccl.so.2.18.1
# INFO 04-28 21:40:18 selector.py:77] Cannot use FlashAttention-2 backend because the flash_attn package is not found. Please install it for better performance.
# INFO 04-28 21:40:18 selector.py:33] Using XFormers backend.
# INFO 04-28 21:40:22 weight_utils.py:199] Using model weights format ['*.safetensors']
# INFO 04-28 21:40:25 model_runner.py:172] Loading model weights took 12.5562 GB
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /workspace/vllm/vllm/lora/punica.py:45, in bgmv(y, x, w_t_all, indicies, layer_idx, scale)
#      44 try:
# ---> 45     import vllm._punica_C as punica_kernels
#      46 except ImportError as e:
#
# ModuleNotFoundError: No module named 'vllm._punica_C'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# /workspace/vllm/notebook.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bremote-server/workspace/vllm/notebook.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from vllm import LLM, SamplingParams
#       <a href='vscode-notebook-cell://ssh-remote%2Bremote-server/workspace/vllm/notebook.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from vllm.lora.request import LoRARequest
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bremote-server/workspace/vllm/notebook.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> llm = LLM(model="meta-llama/Llama-2-7b-hf", enable_lora=True)
#
# File /workspace/vllm/vllm/entrypoints/llm.py:118, in LLM.__init__(self, model, tokenizer, tokenizer_mode, skip_tokenizer_init, trust_remote_code, tensor_parallel_size, dtype, quantization, revision, tokenizer_revision, seed, gpu_memory_utilization, swap_space, enforce_eager, max_context_len_to_capture, disable_custom_all_reduce, **kwargs)
#      98     kwargs["disable_log_stats"] = True
#      99 engine_args = EngineArgs(
#     100     model=model,
#     101     tokenizer=tokenizer,
#    (...)
#     116     **kwargs,
#     117 )
# --> 118 self.llm_engine = LLMEngine.from_engine_args(
#     119     engine_args, usage_context=UsageContext.LLM_CLASS)
#     120 self.request_counter = Counter()
#
# File /workspace/vllm/vllm/engine/llm_engine.py:288, in LLMEngine.from_engine_args(cls, engine_args, usage_context)
#     285     executor_class = GPUExecutor
#     287 # Create the LLM engine.
# --> 288 engine = cls(
#     289     **engine_config.to_dict(),
#     290     executor_class=executor_class,
#     291     log_stats=not engine_args.disable_log_stats,
#     292     usage_context=usage_context,
#     293 )
#     294 return engine
#
# File /workspace/vllm/vllm/engine/llm_engine.py:169, in LLMEngine.__init__(self, model_config, cache_config, parallel_config, scheduler_config, device_config, load_config, lora_config, vision_language_config, speculative_config, decoding_config, executor_class, log_stats, usage_context)
#     154 self.generation_config_fields = _load_generation_config_dict(
#     155     model_config)
#     157 self.model_executor = executor_class(
#     158     model_config=model_config,
#     159     cache_config=cache_config,
#    (...)
#     166     load_config=load_config,
#     167 )
# --> 169 self._initialize_kv_caches()
#     171 # If usage stat is enabled, collect relevant info.
#     172 if is_usage_stats_enabled():
#
# File /workspace/vllm/vllm/engine/llm_engine.py:245, in LLMEngine._initialize_kv_caches(self)
#     238 def _initialize_kv_caches(self) -> None:
#     239     """Initialize the KV cache in the worker(s).
#     240
#     241     The workers will determine the number of blocks in both the GPU cache
#     242     and the swap CPU cache.
#     243     """
#     244     num_gpu_blocks, num_cpu_blocks = (
# --> 245         self.model_executor.determine_num_available_blocks())
#     247     if self.cache_config.num_gpu_blocks_override is not None:
#     248         num_gpu_blocks_override = self.cache_config.num_gpu_blocks_override
#
# File /workspace/vllm/vllm/executor/gpu_executor.py:111, in GPUExecutor.determine_num_available_blocks(self)
#     107 def determine_num_available_blocks(self) -> Tuple[int, int]:
#     108     """Determine the number of available KV blocks by invoking the
#     109     underlying worker.
#     110     """
# --> 111     return self.driver_worker.determine_num_available_blocks()
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /workspace/vllm/vllm/worker/worker.py:138, in Worker.determine_num_available_blocks(self)
#     134 torch.cuda.empty_cache()
#     136 # Execute a forward pass with dummy inputs to profile the memory usage
#     137 # of the model.
# --> 138 self.model_runner.profile_run()
#     140 # Calculate the number of blocks that can be allocated with the
#     141 # profiled peak memory.
#     142 torch.cuda.synchronize()
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /workspace/vllm/vllm/worker/model_runner.py:823, in profile_run(self)
#     810     seq_len = (max_num_batched_tokens // max_num_seqs +
#     811                (group_id < max_num_batched_tokens % max_num_seqs))
#     812     seq_data, fake_multi_modal_input = _prepare_fake_inputs(
#     813         seq_len, self.vision_language_config)
#     814     seq = SequenceGroupMetadata(
#     815         request_id=str(group_id),
#     816         is_prompt=True,
#     817         seq_data={group_id: seq_data},
#     818         sampling_params=sampling_params,
#     819         block_tables=None,
#     820         lora_request=dummy_lora_requests_per_seq[group_id]
#     821         if dummy_lora_requests_per_seq else None,
#     822         multi_modal_data=fake_multi_modal_input,
# --> 823     )
#     824     seqs.append(seq)
#     826 # Run the model with the dummy inputs.
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /workspace/vllm/vllm/worker/model_runner.py:743, in execute_model(self, seq_group_metadata_list, kv_caches)
#     739 else:
#     740     model_executable = self.model
#     741 execute_model_kwargs = {
#     742     "input_ids": input_tokens,
# --> 743     "positions": input_positions,
#     744     "kv_caches": kv_caches,
#     745     "attn_metadata": attn_metadata,
#     746 }
#     747 if self.vision_language_config:
#     748     execute_model_kwargs.update({"image_input": multi_modal_input})
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /workspace/vllm/vllm/model_executor/models/llama.py:364, in LlamaForCausalLM.forward(self, input_ids, positions, kv_caches, attn_metadata)
#     357 def forward(
#     358     self,
#     359     input_ids: torch.Tensor,
#    (...)
#     362     attn_metadata: AttentionMetadata,
#     363 ) -> torch.Tensor:
# --> 364     hidden_states = self.model(input_ids, positions, kv_caches,
#     365                                attn_metadata)
#     366     return hidden_states
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /workspace/vllm/vllm/model_executor/models/llama.py:287, in LlamaModel.forward(self, input_ids, positions, kv_caches, attn_metadata, inputs_embeds)
#     285     hidden_states = inputs_embeds
#     286 else:
# --> 287     hidden_states = self.get_input_embeddings(input_ids)
#     288 residual = None
#     289 for i in range(len(self.layers)):
#
# File /workspace/vllm/vllm/model_executor/models/llama.py:274, in LlamaModel.get_input_embeddings(self, input_ids)
#     273 def get_input_embeddings(self, input_ids: torch.Tensor) -> torch.Tensor:
# --> 274     return self.embed_tokens(input_ids)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /workspace/vllm/vllm/lora/layers.py:331, in VocabParallelEmbeddingWithLoRA.forward(self, x)
#     327 if full_lora_a_embeddings.ndim == 3:
#     328     full_lora_a_embeddings = full_lora_a_embeddings.view(
#     329         full_lora_a_embeddings.shape[0] *
#     330         full_lora_a_embeddings.shape[1], -1)
# --> 331 bgmv(full_output, full_lora_a_embeddings, self.lora_b_stacked,
#     332      self.indices[:self.indices_len[0]], 0, 1.0)
#     333 return full_output.view_as(full_output_org)
#
# File /workspace/vllm/vllm/lora/punica.py:47, in bgmv(y, x, w_t_all, indicies, layer_idx, scale)
#      45     import vllm._punica_C as punica_kernels
#      46 except ImportError as e:
# ---> 47     _raise_import_error(e)
#      49 punica_kernels.dispatch_bgmv(y, x, w_t_all, indicies, layer_idx, scale)
#
# File /workspace/vllm/vllm/lora/punica.py:13, in _raise_import_error(e)
#      10     raise ImportError(
#      11         "punica LoRA kernels require compute capability >= 8.0") from e
#      12 else:
# ---> 13     raise ImportError(
#      14         "punica LoRA kernels could not be imported. If you built vLLM "
#      15         "from source, make sure VLLM_INSTALL_PUNICA_KERNELS=1 env var "
#      16         "was set.") from e
#
# ImportError: punica LoRA kernels could not be imported. If you built vLLM from source, make sure VLLM_INSTALL_PUNICA_KERNELS=1 env var was set.

# %%
sampling_params = SamplingParams(
    temperature=0,
    max_tokens=256,
    stop=["[/assistant]"]
)

prompts = [
     "[user] Write a SQL query to answer the question based on the table schema.\n\n context: CREATE TABLE table_name_74 (icao VARCHAR, airport VARCHAR)\n\n question: Name the ICAO for lilongwe international airport [/user] [assistant]",
     "[user] Write a SQL query to answer the question based on the table schema.\n\n context: CREATE TABLE table_name_11 (nationality VARCHAR, elector VARCHAR)\n\n question: When Anchero Pantaleone was the elector what is under nationality? [/user] [assistant]",
]

outputs = llm.generate(
    prompts,
    sampling_params,
    lora_request=LoRARequest("sql_adapter", 1, sql_lora_path)
)
