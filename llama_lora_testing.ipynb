# %%
from huggingface_hub import snapshot_download
from vllm.lora.request import LoRARequest

sql_lora_path = snapshot_download(repo_id="yard1/llama-2-7b-sql-lora-test")
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/91.0 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/556 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/697 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/41.2M [00:00<?, ?B/s]
# new_embeddings.safetensors:   0%|          | 0.00/65.7k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]

# %%
lora_request=LoRARequest("testing adapter", 1, sql_lora_path)
lora_request.lora_local_path
# Out:
# '/home/ray/.cache/huggingface/hub/models--yard1--llama-2-7b-sql-lora-test/snapshots/0dfa347e8877a4d4ed19ee56c140fa518470028c'

# %%
import torch
from safetensors.torch import load

with open(lora_request.lora_local_path + '/adapter_model.safetensors', 'rb') as f:
    data_bytes = f.read()

data = load(data_bytes)
# lora_state_dict = torch.load(lora_request.lora_local_path+'/adapter_model.safetensors')

# %%
data.keys()
# Out:
# dict_keys(['base_model.model.model.layers.27.self_attn.k_proj.lora_A.weight', 'base_model.model.model.layers.24.self_attn.q_proj.lora_A.weight', 'base_model.model.model.layers.11.mlp.gate_proj.lora_A.weight', 'base_model.model.model.layers.19.mlp.down_proj.lora_B.weight', 'base_model.model.model.layers.7.self_attn.k_proj.lora_A.weight', 'base_model.model.model.layers.27.self_attn.q_proj.lora_B.weight', 'base_model.model.model.layers.15.mlp.down_proj.lora_A.weight', 'base_model.model.model.layers.2.mlp.up_proj.lora_B.weight', 'base_model.model.model.layers.31.self_attn.o_proj.lora_B.weight', 'base_model.model.model.layers.2.mlp.up_proj.lora_A.weight', 'base_model.model.model.layers.8.mlp.up_proj.lora_A.weight', 'base_model.model.model.layers.28.mlp.down_proj.lora_A.weight', 'base_model.model.model.layers.6.mlp.gate_proj.lora_A.weight', 'base_model.model.model.layers.5.self_attn.o_proj.lora_A.weight', 'base_model.model.model.layers.13.self_attn.v_proj.lora_A.weight', 'base_model.model.
# ...

# %%
from vllm import LLM, SamplingParams
from vllm.lora.request import LoRARequest

llm = LLM(model="meta-llama/Llama-2-7b-hf", enable_lora=True, dtype="float16", enforce_eager=True)
# Out:
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# INFO 03-11 23:59:01 llm_engine.py:79] Initializing an LLM engine with config: model='meta-llama/Llama-2-7b-hf', tokenizer='meta-llama/Llama-2-7b-hf', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=auto, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, kv_cache_dtype=auto, device_config=cuda, seed=0)
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# UNPADDED 32000
# PADDED 32256
# ...
